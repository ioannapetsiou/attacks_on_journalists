# %% [markdown]
# ### In this notebook I am getting data from [CPJ](https://cpj.org/data/) on the imprisoned Journalists from 1992 to 2023.

# %%
#importing necessary modules
import pandas as pd

# %%
# What did I do to get here:
# 1. I went onto the database, right-clicked and selected "inspect elements"
# 2. I went onto "Network" and I copied the undocumented API as bash
# 3. I went onto curl converter and pasted what I had copied.
# 4. The result below is what I got from Curl converter
import requests

headers = {
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-language': 'el-GR,el;q=0.9,en;q=0.8',
    'origin': 'https://cpj.org',
    'priority': 'u=1, i',
    'referer': 'https://cpj.org/',
    'sec-ch-ua': '"Not)A;Brand";v="99", "Google Chrome";v="127", "Chromium";v="127"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36',
}

response = requests.get(
    'https://datamanager.cpj.org/api/datamanager/reports/entries?distinct(personId)&includes=organizations,fullName,location,status,typeOfDeath,charges,startDisplay,mtpage,country,type,motiveConfirmed&sort=fullName&pageNum=2&pageSize=20&in(status,%27Imprisoned%27)&ge(year,1992)&le(year,2023)',
    headers=headers,
)

# %%
# if response == 200 we are good to go
response
# Out:
# <Response [200]>

# %%
# saving the response as data and then printing it
data = response.json()
data
# Out:
# {'rowCount': 2232,
#  'pageNum': 2,
#  'pageSize': '20',
#  'pageCount': 112,
#  'data': [{'organizations': 'Algerian Press Service',
#    'fullName': 'Abdelkader Hadj Benaamane',
#    'location': None,
#    'status': 'Imprisoned',
#    'typeOfDeath': None,
#    'charges': 'Anti-State',
#    'startDisplay': 'February 28, 1995',
#    'mtpage': 'https://cpj.org/data/people/abdelkader-hadj-benaamane/',
#    'country': 'Algeria',
#    'type': 'Journalist',
#    'motiveConfirmed': None},
#   {'organizations': 'Freelance',
#    'fullName': 'Abdelmoundji Khelladi',
#    'location': 'Constantine',
#    'status': 'Imprisoned',
#    'typeOfDeath': None,
#    'charges': 'Anti-state',
#    'startDisplay': 'October 7, 2019',
#    'mtpage': 'https://cpj.org/data/people/abdelmoundji-khelladi/',
#    'country': 'Algeria',
#    'type': 'Journalist',
#    'motiveConfirmed': None},
#   {'organizations': 'Karmoz',
#    'fullName': 'Abdelrahman Abdelsalam Yaqot',
#    'location': None,
#    'status': 'Imprisoned',
#    'typeOfDeath': None,
#    'charges': 'Anti-State, Retaliatory',
#    'startDisplay': 'March 21, 2015',
#    'mtpage': 'https://cpj.org/data/people/abdelrahman-abdelsalam-yaqot/',
#    'country': 'Egypt',
#    'type': 'Journalist',
#    'motiveConfirmed': None},
#   {'organizations': 'Al-Mesryoon',
#    'fullName': 'Abdelrahman Abu Ouf',
#    'location': None,
#    'status': 'Imprisoned',
#    'typeOfDeath': None,
#    'charges': 'Anti-State',
#    'startDisplay': 'November 14, 2015',
#    'mtpage': 'https://cpj.org/data/people/abdelrahman-abu-ouf/',
#    'country': 'Egypt',
#    'type': 'Journalist',
#    'motiveConfirmed': None},
#   {'organizations': 'Radio Dabanga',
#    'fullName': 'Abdelrahman Adam Abdelrahman',
#    'location': None,
#    'status': 'Imprisoned',
#    'typeOfDeath': None,
#    'charges': 'Anti-State',
#    'startDisplay': 'October 30, 2010',
#    'mtpage': 'https://cpj.org/data/people/abdelrahman-adam-abdelrahman/',
#    'country': 'Sudan',
#    'type': 'Journalist',
#    'motiveConfirmed': None},
#   {'organizations': 'Shabelle Media Network',
#    'fullName': 'Abdimalik Yusuf',
#    'location': None,
#    'status': 'Imprisoned',
#    'typeOfDeath': None,
#    'charges': 'No charge disclosed',
#    'startDisplay': 'November 22, 2013',
#    'mtpage': 'https://cpj.org/data/people/abdimalik-yusuf/',
#    'country': 'Somalia',
#    'type': 'Journalist',
#    'motiveConfirmed': None},
#   {'organizations': 'Horn Cable TV',
#    'fullName': 'Abdiqaadir Saleban Aseyr',
#    'location': 'Hargeisa',
#    'status': 'Imprisoned',
#    'typeOfDeath': None,
#    'charges': 'No charge disclosed',
#    'startDisplay': 'November 18, 2019',
#    'mtpage': 'https://cpj.org/data/people/abdiqaadir-saleban-aseyr/',
#    'country': 'Somalia',
#    'type': 'Journalist',
#    'motiveConfirmed': None},
#   {'organizations': 'Hubsad',
#    'fullName': "Abdirashid Nur Wa'ays",
#    'location': None,
#    'status': 'Imprisoned',
#    'typeOfDeath': None,
#    'charges': 'False News, Retaliatory',
#    'startDisplay': 'November 30, 2015',
#    'mtpage': 'https://cpj.org/data/people/abdirashid-nur-waays/',
#    'country': 'Somalia',
#    'type': 'Journalist',
#    'motiveConfirmed': None},
#   {'organizations': 'Freelance',
#    'fullName': 'Abdo Fayed',
#    'location': 'Cairo',
#    'status': 'Imprisoned',
#    'typeOfDeath': None,
#    'charges': 'Anti-state, False News',
#    'startDisplay': 'May 26, 2020',
#    'mtpage': 'https://cpj.org/data/people/abdo-fayed/',
#    'country': 'Egypt',
#    'type': 'Journalist',
#    'motiveConfirmed': None},
#   {'organizations': 'Freelance',
#    'fullName': 'Abdolreza Tajik',
#    'location': None,
#    'status': 'Imprisoned',
#    'typeOfDeath': None,
#    'charges': 'Anti-State',
#    'startDisplay': 'June 12, 2010',
#    'mtpage': 'https://cpj.org/data/people/abdolreza-tajik/',
#    'country': 'Iran',
#    'type': 'Journalist',
#    'motiveConfirmed': None},
#   {'organizations': 'Le Canard Déchaîné',
#    'fullName': 'Abdoulaye Tiémogo',
#    'location': None,
#    'status': 'Imprisoned',
#    'typeOfDeath': None,
#    'charges': 'Defamation',
#    'startDisplay': 'June 18, 2002',
#    'mtpage': 'https://cpj.org/data/people/abdoulaye-tiemogo/',
#    'country': 'Niger',
#    'type': 'Journalist',
#    'motiveConfirmed': None},
#   {'organizations': 'CBS News',
#    'fullName': 'Abdul Ameer Younis Hussein',
#    'location': None,
#    'status': 'Imprisoned',
#    'typeOfDeath': None,
#    'charges': 'No charge disclosed',
#    'startDisplay': 'Custody of U.S. | April 5, 2005',
#    'mtpage': 'https://cpj.org/data/people/abdul-ameer-younis-hussein/',
#    'country': 'Iraq',
#    'type': 'Journalist',
#    'motiveConfirmed': None},
#   {'organizations': 'Freelance',
#    'fullName': 'Abdul Aziz al-Baz',
#    'location': None,
#    'status': 'Imprisoned',
#    'typeOfDeath': None,
#    'charges': 'Ethnic or religious insult',
#    'startDisplay': 'December 31, 2012',
#    'mtpage': 'https://cpj.org/data/people/abdul-aziz-al-baz/',
#    'country': 'Kuwait',
#    'type': 'Journalist',
#    'motiveConfirmed': None},
#   {'organizations': 'Freelance',
#    'fullName': 'Abdulelah Hider Shaea',
#    'location': None,
#    'status': 'Imprisoned',
#    'typeOfDeath': None,
#    'charges': 'Anti-State',
#    'startDisplay': 'August 16, 2010',
#    'mtpage': 'https://cpj.org/data/people/abdulelah-hider-shaea/',
#    'country': 'Yemen',
#    'type': 'Journalist',
#    'motiveConfirmed': None},
#   {'organizations': 'East Turkistan Information Center',
#    'fullName': 'Abdulghani Memetemin',
#    'location': None,
#    'status': 'Imprisoned',
#    'typeOfDeath': None,
#    'charges': 'Anti-State',
#    'startDisplay': 'July 26, 2002',
#    'mtpage': 'https://cpj.org/data/people/abdulghani-memetemin/',
#    'country': 'China',
#    'type': 'Journalist',
#    'motiveConfirmed': None},
#   {'organizations': 'Freelance',
#    'fullName': 'Abduljalil Alsingace',
#    'location': None,
#    'status': 'Imprisoned',
#    'typeOfDeath': None,
#    'charges': 'Anti-State',
#    'startDisplay': 'August 13, 2010',
#    'mtpage': 'https://cpj.org/data/people/abduljalil-alsingace/',
#    'country': 'Bahrain',
#    'type': 'Journalist',
#    'motiveConfirmed': None},
#   {'organizations': 'Freelance',
#    'fullName': 'Abduljalil Alsingace',
#    'location': 'Busaiteen',
#    'status': 'Imprisoned',
#    'typeOfDeath': None,
#    'charges': 'Anti-state',
#    'startDisplay': 'March 17, 2011',
#    'mtpage': 'https://cpj.org/data/people/abduljalil-alsingace/',
#    'country': 'Bahrain',
#    'type': 'Journalist',
#    'motiveConfirmed': None},
#   {'organizations': 'Freelance',
#    'fullName': 'Abdullah al-Duhailan',
#    'location': 'Dammam, Eastern Province',
#    'status': 'Imprisoned',
#    'typeOfDeath': None,
#    'charges': 'No charge disclosed',
#    'startDisplay': 'April 4, 2019',
#    'mtpage': 'https://cpj.org/data/people/abdullah-al-duhailan/',
#    'country': 'Saudi Arabia',
#    'type': 'Journalist',
#    'motiveConfirmed': None},
#   {'organizations': 'Rassd',
#    'fullName': 'Abdullah al-Fakharany',
#    'location': 'Cairo',
#    'status': 'Imprisoned',
#    'typeOfDeath': None,
#    'charges': 'Anti-state',
#    'startDisplay': 'August 25, 2013',
#    'mtpage': 'https://cpj.org/data/people/abdullah-al-fakharany/',
#    'country': 'Egypt',
#    'type': 'Journalist',
#    'motiveConfirmed': None},
#   {'organizations': 'Al-Jazeera',
#    'fullName': 'Abdullah al-Shami',
#    'location': None,
#    'status': 'Imprisoned',
#    'typeOfDeath': None,
#    'charges': 'No charge disclosed',
#    'startDisplay': 'August 14, 2013',
#    'mtpage': 'https://cpj.org/data/people/abdullah-al-shami/',
#    'country': 'Egypt',
#    'type': 'Journalist',
#    'motiveConfirmed': None}]}

# %% [markdown]
# ### The steps above are for one seperate page. Below we will do that for all pages

# %%
# the first part is the same as above
import requests

headers = {
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-language': 'el-GR,el;q=0.9,en;q=0.8',
    'origin': 'https://cpj.org',
    'priority': 'u=1, i',
    'referer': 'https://cpj.org/',
    'sec-ch-ua': '"Not)A;Brand";v="99", "Google Chrome";v="127", "Chromium";v="127"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36',
}
# we set the base url as base
base_url = 'https://datamanager.cpj.org/api/datamanager/reports/entries'
#and create the params based on what the first url we used has. For example, in the second cell we see that the url is:
#https://datamanager.cpj.org/api/datamanager/reports/entries?distinct(personId)&includes=organizations,fullName,location,status,typeOfDeath,charges,startDisplay,mtpage,country,type,motiveConfirmed&sort=fullName&pageNum=2&pageSize=20&in(status,%27Imprisoned%27)&ge(year,1992)&le(year,2023)
# the first part is the base url (as mentioned)
#then all params are what follows
params = {
    'distinct': 'personId',
    'includes': 'organizations,fullName,location,status,typeOfDeath,charges,startDisplay,mtpage,country,type,motiveConfirmed',
    'sort': '-fullName',
    'pageNum': 1,
    'pageSize': 20,
    'in': 'status,\'Imprisoned\'',
    'ge': 'year,1992',
    'le': 'year,2023'
}

#we create an empty list to store the results
all_results = []
# we need a while loop because we don't know for how many pages is this needed
while True:
    # and we do the same as before, but now for all pages
    response = requests.get(base_url, headers=headers, params=params)
    data = response.json()
    
    # appending the current page of results to the all_results list
    all_results.extend(data.get('data', []))
    
    # checking to see if there are more pages
    current_page = data.get('pageNum', 1)
    total_pages = data.get('pageCount', 1)
    
    if current_page >= total_pages:
        break
    
    # updating the page number to get the next page of results
    params['pageNum'] += 1

# here i print all the results to see if it worked
print(all_results)
# Out:
# [{'organizations': 'Dicle News Agency', 'fullName': 'Zuhal Tekiner', 'location': None, 'status': 'Imprisoned', 'typeOfDeath': None, 'charges': 'Anti-State', 'startDisplay': 'December 20, 2011', 'mtpage': 'https://cpj.org/data/people/zuhal-tekiner/', 'country': 'Turkey', 'type': 'Journalist', 'motiveConfirmed': None}, {'organizations': 'Freelance', 'fullName': 'Zuhair Makhlouf', 'location': None, 'status': 'Imprisoned', 'typeOfDeath': None, 'charges': 'Censorship Violation', 'startDisplay': 'October 20, 2009', 'mtpage': 'https://cpj.org/data/people/zuhair-makhlouf/', 'country': 'Tunisia', 'type': 'Journalist', 'motiveConfirmed': None}, {'organizations': 'Freelance', 'fullName': 'Zuhair Kutbi', 'location': None, 'status': 'Imprisoned', 'typeOfDeath': None, 'charges': 'No charge disclosed', 'startDisplay': 'January 10, 2019', 'mtpage': 'https://cpj.org/data/people/zuhair-kutbi/', 'country': 'Saudi Arabia', 'type': 'Journalist', 'motiveConfirmed': None}, {'organizations': 'Roj News', 'fullName': 'Zuber Bradosti', 'location': 'Masif', 'status': 'Imprisoned', 'typeOfDeath': None, 'charges': 'No charge disclosed', 'startDisplay': 'July 21, 2019', 'mtpage': 'https://cpj.org/data/people/zuber-bradosti/', 'country': 'Iraq', 'type': 'Journalist', 'motiveConfirmed': None}, {'organizations': 'TUNeZINE', 'fullName': 'Zouhair Yahyaoui', 'location': None, 'status': 'Imprisoned', 'typeOfDeath': None, 'charges': 'False News', 'startDisplay': 'June 4, 2002', 'mtpage': 'https://cpj.org/data/people/zouhair-yahyaoui/', 'country': 'Tunisia', 'type': 'Journalist', 'motiveConfirmed': None}, {'organizations': 'Aswar Press Agency', 'fullName': 'Ziyad Awad', 'location': None, 'status': 'Imprisoned', 'typeOfDeath': None, 'charges': 'No charge disclosed', 'startDisplay': 'November 22, 2011', 'mtpage': 'https://cpj.org/data/people/ziyad-awad/', 'country': 'Israel and the Occupied Palestinian Territory', 'type': 'Journalist', 'motiveConfirmed': None}, {'organizations': 'Özgür Gündem', 'fullName': 'Ziya Çiçekçi', 'location': None, 'status': 'Imprisoned', 'typeOfDeath': None, 'charges': 'Anti-State', 'startDisplay': 'December 20, 2011', 'mtpage': 'https://cpj.org/data/people/ziya-cicekci/', 'country': 'Turkey', 'type': 'Journalist', 'motiveConfirmed': None}, {'organizations': 'Azadliq', 'fullName': 'Ziya Asadli', 'location': None, 'status': 'Imprisoned', 'typeOfDeath': None, 'charges': 'Retaliatory', 'startDisplay': 'September 5, 2017', 'mtpage': 'https://cpj.org/data/people/ziya-asadli/', 'country': 'Azerbaijan', 'type': 'Journalist', 'motiveConfirmed': None}, {'organizations': 'Beijing TV', 'fullName': 'Zi Beijia', 'location': None, 'status': 'Imprisoned', 'typeOfDeath': None, 'charges': 'False News', 'startDisplay': 'July 18, 2007', 'mtpage': 'https://cpj.org/data/people/zi-beijia/', 'country': 'China', 'type': 'Journalist', 'motiveConfirmed': None}, {'organizations': 'Freelance', 'fullName': 'Zhuo Zhiqiang', 'location': None, 'status': 'Imprisoned', 'typeOfDeath': None, 'charges': 'Defamation', 'startDisplay': '2013 or 2014', 'mtpage': 'https://cpj.org/data/people/zhuo-zhiqiang/', 'country': 'China', 'type': 'Journalist', 'motiveConfirmed': None}, {'organizations': 'Zaiye Dang', 'fullName': 'Zhu Yufu', 'location': None, 'status': 'Imprisoned', 'typeOfDeath': None, 'charges': 'Anti-State', 'startDisplay': 'September 1999', 'mtpage': 'https://cpj.org/data/people/zhu-yufu/', 'country': 'China', 'type': 'Journalist', 'motiveConfirmed': None}, {'organizations': 'Freelance', 'fullName': 'Zhu Ruixiang', 'location': None, 'status': 'Imprisoned', 'typeOfDeath': None, 'charges': 'Anti-State', 'startDisplay': 'May 9, 2001', 'mtpage': 'https://cpj.org/data/people/zhu-ruixiang/', 'country': 'China', 'type': 'Journalist', 'motiveConfirmed': None}, {'organizations': 'Sound of the Bell', 'fullName': 'Zhu Jianbin', 'location': None, 'status': 'Imprisoned', 'typeOfDeath': None, 'charges': None, 'startDisplay': 'April 1981', 'mtpage': 'https://cpj.org/data/people/zhu-jianbin ...

# %%
# I have a list of dictionaries that I turn into a dataframe
df = pd.DataFrame(all_results)
df
# Out:
#                  organizations          fullName    location      status  \
# 0            Dicle News Agency     Zuhal Tekiner        None  Imprisoned
# 1                    Freelance   Zuhair Makhlouf        None  Imprisoned
# 2                    Freelance      Zuhair Kutbi        None  Imprisoned
# 3                     Roj News    Zuber Bradosti       Masif  Imprisoned
# 4                     TUNeZINE  Zouhair Yahyaoui        None  Imprisoned
# ...                        ...               ...         ...         ...
# 2227                     Salam        Abbas Abdi        None  Imprisoned
# 2228  Amara Media Center (AMC)        Abay Zewdu  Awash Arba  Imprisoned
# 2229           Agiere, Welafen        Abay Hailu        None  Imprisoned
# 2230          Kashmir Narrator      Aasif Sultan        Agra  Imprisoned
# 2231                 Freelance  Aamer Abdelmonem       Cairo  Imprisoned
#
#      typeOfDeath                 charges       startDisplay  \
# 0           None              Anti-State  December 20, 2011
# 1           None    Censorship Violation   October 20, 2009
# 2           None     No charge disclosed   January 10, 2019
# 3           None     No charge disclosed      July 21, 2019
# 4           None              False News       June 4, 2002
# ...          ...                     ...                ...
# 2227        None                    None   Late August 1993
# 2228        None     No charge disclosed    August 10, 2023
# 2229        None                    None  February 22, 1997
# 2230        None              Anti-state    August 27, 2018
# 2231        None  Anti-state, False News  December 19, 2020
#
#                                              mtpage       country        type  \
# 0        https://cpj.org/data/people/zuhal-tekiner/        Turkey  Journalist
# 1      https://cpj.org/data/people/zuhair-makhlouf/       Tunisia  Journalist
# 2         https://cpj.org/data/people/zuhair-kutbi/  Saudi Arabia  Journalist
# 3       https://cpj.org/data/people/zuber-bradosti/          Iraq  Journalist
# 4     https://cpj.org/data/people/zouhair-yahyaoui/       Tunisia  Journalist
# ...                                             ...           ...         ...
# 2227        https://cpj.org/data/people/abbas-abdi/          Iran  Journalist
# 2228      https://cpj.org/data/people/abay-zewdu-2/      Ethiopia  Journalist
# 2229        https://cpj.org/data/people/abay-hailu/      Ethiopia  Journalist
# 2230      https://cpj.org/data/people/aasif-sultan/         India  Journalist
# 2231  https://cpj.org/data/people/aamer-abdelmonem/         Egypt  Journalist
#
#      motiveConfirmed
# 0               None
# 1               None
# 2               None
# 3               None
# 4               None
# ...              ...
# 2227            None
# 2228            None
# 2229            None
# 2230            None
# 2231            None
#
# [2232 rows x 11 columns]

# %%
#I save my results as a .csv and .xlsx files
df.to_csv("CPJ_imprisoned.csv")
df.to_excel("CPJ_imprisoned.xlsx")
